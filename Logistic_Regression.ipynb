# %%
# %matplotlib inline
import matplotlib as plt
import pandas as pd
import os
import numpy as np

# %%
#import our train and test csv
train_path = os.path.join("Data/train.csv")
train_df = pd.read_csv(train_path)

test_path = os.path.join("Data/test.csv")
test_df = pd.read_csv(test_path)

# %%
train_df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
test_df.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %%
len(test_df)
# Out:
# 25976

# %%
test_df = test_df.dropna()

# %%
len(test_df)
# Out:
# 25893

# %%
test_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
len(train_df)
# Out:
# 103594

# %%
train_df = train_df.dropna()

# %%
train_df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103589      103899   94171  Female  disloyal Customer   23  Business travel
# 103590      103900   73097    Male     Loyal Customer   49  Business travel
# 103591      103901   68825    Male  disloyal Customer   30  Business travel
# 103592      103902   54173  Female  disloyal Customer   22  Business travel
# 103593      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
train_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
#convert the satisfaction column to 1's and 0's
train_df["satisfaction"].replace({"satisfied":1, "neutral or dissatisfied":0}, inplace=True)

# %%
#assign the X_train data
X_train = np.array(train_df[['Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']]).reshape(-1,17)

#assign the y_train data
y_train = np.array(train_df["satisfaction"]).reshape(-1,1)

# %%
X_train[0]
# Out:
# array([460.,   3.,   4.,   3.,   1.,   5.,   3.,   5.,   5.,   4.,   3.,
#          4.,   4.,   5.,   5.,  25.,  18.])

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# C:\Users\colin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\colin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#convert the satisfaction column to 1's and 0's
test_df["satisfaction"].replace({"satisfied":1, "neutral or dissatisfied":0}, inplace=True)

# %%
X_test = np.array(test_df[['Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']]).reshape(-1,17)
y_test = np.array(test_df["satisfaction"]).reshape(-1,1)

# %%
y_test
# Out:
# array([[1],
#        [1],
#        [0],
#        ...,
#        [0],
#        [1],
#        [0]], dtype=int64)

# %%
print(f'Training Data Score: {classifier.score(X_train, y_train) * 100}%') # 66%
print(f'Testing Data Score: {classifier.score(X_test, y_test) * 100}%') # 66%
# Out:
# Training Data Score: 73.6297468965384%
# Testing Data Score: 74.01614335920905%

# %%
#predict the new data point
predictions = classifier.predict(X_test)
y_test_ = np.array(test_df["satisfaction"])

prediction_df = pd.DataFrame({"Prediction":predictions, "Actual":y_test_})
prediction_df
# Out:
#        Prediction  Actual
# 0               1       1
# 1               1       1
# 2               0       0
# 3               1       1
# 4               0       1
# ...           ...     ...
# 25888           0       0
# 25889           0       1
# 25890           0       0
# 25891           0       1
# 25892           0       0
#
# [25893 rows x 2 columns]
